# %% [markdown]
# <a href="https://colab.research.google.com/github/EricSnunes/AnaliseDeDados/blob/main/WebScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.6)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
url = 'https://www.uol.com.br/esporte/futebol/campeonatos/ingles/'
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
if response.status_code == 200:
  soup = BeautifulSoup(response.content,'html.parser')
  table = soup.find('table')
  if table:
    data =[]
    rows = table.find_all('tr')
    for row in rows:
      cols = row.find_all(['td','th'])
      cols = [col.text.strip() for col in cols]
      data.append(cols)

      df = pd.DataFrame(data[1:], columns=data[0])

      print(df)

      df.to_csv('tabela_extraida.csv', index=False)
    else:
          print('Tabela não encontrada')
  else:
            print('Erro ao acessar a página:', response.status_code)
# Out:
# Empty DataFrame
# Columns: [classificação]
# Index: []
#             classificação
# 0  1°  Manchester CityCIT
#             classificação
# 0  1°  Manchester CityCIT
# 1          2°  ArsenalARS
#              classificação
# 0   1°  Manchester CityCIT
# 1           2°  ArsenalARS
# 2  3°  Newcastle UnitedNEW
#              classificação
# 0   1°  Manchester CityCIT
# 1           2°  ArsenalARS
# 2  3°  Newcastle UnitedNEW
# 3         4°  LiverpoolLIV
#              classificação
# 0   1°  Manchester CityCIT
# 1           2°  ArsenalARS
# 2  3°  Newcastle UnitedNEW
# 3         4°  LiverpoolLIV
# 4       5°  Aston VillaAST
#              classificação
# 0   1°  Manchester CityCIT
# 1           2°  ArsenalARS
# 2  3°  Newcastle UnitedNEW
# 3         4°  LiverpoolLIV
# 4       5°  Aston VillaAST
# 5          6°  BrightonBHA
#               classificação
# 0    1°  Manchester CityCIT
# 1            2°  ArsenalARS
# 2   3°  Newcastle UnitedNEW
# 3          4°  LiverpoolLIV
# 4        5°  Aston VillaAST
# 5           6°  BrightonBHA
# 6  7°  Nottingham ForestNOT
#               classificação
# 0    1°  Manchester CityCIT
# 1            2°  ArsenalARS
# 2   3°  Newcastle UnitedNEW
# 3          4°  LiverpoolLIV
# 4        5°  Aston VillaAST
# 5           6°  BrightonBHA
# 6  7°  Nottingham ForestNOT
# 7            8°  ChelseaCHE
#               classificação
# 0    1°  Manchester CityCIT
# 1            2°  ArsenalARS
# 2   3°  Newcastle UnitedNEW
# 3          4°  LiverpoolLIV
# 4        5°  Aston VillaAST
# 5           6°  BrightonBHA
# 6  7°  Nottingham ForestNOT
# 7            8°  ChelseaCHE
# 8          9°  BrentfordBTF
#                classificação
# 0     1°  Manchester CityCIT
# 1             2°  ArsenalARS
# 2    3°  Newcastle UnitedNEW
# 3           4°  LiverpoolLIV
# 4         5°  Aston VillaAST
# 5            6°  BrightonBHA
# 6   7°  Nottingham ForestNOT
# 7             8°  ChelseaCHE
# 8           9°  BrentfordBTF
# 9  10°  Manchester UnitedMAN
#                 classificação
# 0      1°  Manchester CityCIT
# 1              2°  ArsenalARS
# 2     3°  Newcastle UnitedNEW
# 3            4°  LiverpoolLIV
# 4          5°  Aston VillaAST
# 5             6°  BrightonBHA
# 6    7°  Nottingham ForestNOT
# 7              8°  ChelseaCHE
# 8            9°  BrentfordBTF
# 9   10°  Manchester UnitedMAN
# 10        11°  BournemouthBTH
#                 classificação
# 0      1°  Manchester CityCIT
# 1              2°  ArsenalARS
# 2     3°  Newcastle UnitedNEW
# 3            4°  LiverpoolLIV
# 4          5°  Aston VillaAST
# 5             6°  BrightonBHA
# 6    7°  Nottingham ForestNOT
# 7              8°  ChelseaCHE
# 8            9°  BrentfordBTF
# 9   10°  Manchester UnitedMAN
# 10        11°  BournemouthBTH
# 11             12°  FulhamFUL
#                 classificação
# 0      1°  Manchester CityCIT
# 1              2°  ArsenalARS
# 2     3°  Newcastle UnitedNEW
# 3            4°  LiverpoolLIV
# 4          5°  Aston VillaAST
# 5             6°  BrightonBHA
# 6    7°  Nottingham ForestNOT
# 7              8°  ChelseaCHE
# 8            9°  BrentfordBTF
# 9   10°  Manchester UnitedMAN
# 10        11°  BournemouthBTH
# 11             12°  FulhamFUL
# 12          13°  TottenhamTOT
#                 classificação
# 0      1°  Manchester CityCIT
# 1              2°  ArsenalARS
# 2     3°  Newcastle UnitedNEW
# 3            4°  LiverpoolLIV
# 4          5°  Aston VillaAST
# 5             6°  BrightonBHA
# 6    7°  Nottingham ForestNOT
# 7              8°  ChelseaCHE
# 8            9°  BrentfordBTF
# 9   10°  Manchester UnitedMAN
# 10        11°  BournemouthBTH
# 11             12°  FulhamFUL
# 12          13°  TottenhamTOT
# 13           14°  West HamWHM
#                 classificação
# 0      1°  Manchester CityCIT
# 1              2°  ArsenalARS
# 2     3°  Newcastle UnitedNEW
# 3            4°  LiverpoolLIV
# 4          5°  Aston VillaAST
# 5             6°  BrightonBHA
# 6    7°  Nottingham ForestNOT
# 7              8°  ChelseaCHE
# 8            9°  BrentfordBTF
# 9   10°  Manchester UnitedMAN
# 10        11°  BournemouthBTH
# 11             12°  FulhamFUL
# 12          13°  TottenhamTOT
# 13           14°  West HamWHM
# 14     15°  Leicester CityLEI
#                 classificação
# 0      1°  Manchester CityCIT
# 1              2°  ArsenalARS
# 2     3°  Newcastle UnitedNEW
# 3            4°  LiverpoolLIV
# 4          5°  Aston VillaAST
# 5             6°  BrightonBHA
# 6    7°  Nottingham ForestNOT
# 7              8°  ChelseaCHE
# 8            9°  BrentfordBTF
# 9   10°  Manchester UnitedMAN
# 10        11°  BournemouthBTH
# 11             12°  FulhamFUL
# 12          13°  TottenhamTOT
# 13           14°  West HamWHM
# 14     15°  Leicester CityLEI
# 15     16°  Crystal PalaceCRY
#                 classificação
# 0      1°  Manchester CityCIT
# 1              2°  ArsenalARS
# 2     3°  Newcastle UnitedNEW
# 3            4°  LiverpoolLIV
# 4          5°  Aston VillaAST
# 5             6°  BrightonBHA
# 6    7°  Nottingham ForestNOT
# 7              8°  ChelseaCHE
# 8            9°  BrentfordBTF
# 9   10°  Manchester UnitedMAN
# 10        11°  BournemouthBTH
# 11             12°  FulhamFUL
# 12          13°  TottenhamTOT
# 13           14°  West HamWHM
# 14     15°  Leicester CityLEI
# 15     16°  Crystal PalaceCRY
# 16       17°  Ipswich TownIPS
#                 classificação
# 0      1°  Manchester CityCIT
# 1              2°  ArsenalARS
# 2     3°  Newcastle UnitedNEW
# 3            4°  LiverpoolLIV
# 4          5°  Aston VillaAST
# 5             6°  BrightonBHA
# 6    7°  Nottingham ForestNOT
# 7              8°  ChelseaCHE
# 8            9°  BrentfordBTF
# 9   10°  Manchester UnitedMAN
# 10        11°  BournemouthBTH
# 11             12°  FulhamFUL
# 12          13°  TottenhamTOT
# 13           14°  West HamWHM
# 14     15°  Leicester CityLEI
# 15     16°  Crystal PalaceCRY
# 16       17°  Ipswich TownIPS
# 17      18°  WolverhamptonWOL
#                 classificação
# 0      1°  Manchester CityCIT
# 1              2°  ArsenalARS
# 2     3°  Newcastle UnitedNEW
# 3            4°  LiverpoolLIV
# 4          5°  Aston VillaAST
# 5             6°  BrightonBHA
# 6    7°  Nottingham ForestNOT
# 7              8°  ChelseaCHE
# 8            9°  BrentfordBTF
# 9   10°  Manchester UnitedMAN
# 10        11°  BournemouthBTH
# 11             12°  FulhamFUL
# 12          13°  TottenhamTOT
# 13           14°  West HamWHM
# 14     15°  Leicester CityLEI
# 15     16°  Crystal PalaceCRY
# 16       17°  Ipswich TownIPS
# 17      18°  WolverhamptonWOL
# 18        19°  SouthamptonSOU
#                 classificação
# 0      1°  Manchester CityCIT
# 1              2°  ArsenalARS
# 2     3°  Newcastle UnitedNEW
# 3            4°  LiverpoolLIV
# 4          5°  Aston VillaAST
# 5             6°  BrightonBHA
# 6    7°  Nottingham ForestNOT
# 7              8°  ChelseaCHE
# 8            9°  BrentfordBTF
# 9   10°  Manchester UnitedMAN
# 10        11°  BournemouthBTH
# 11             12°  FulhamFUL
# 12          13°  TottenhamTOT
# 13           14°  West HamWHM
# 14     15°  Leicester CityLEI
# 15     16°  Crystal PalaceCRY
# 16       17°  Ipswich TownIPS
# 17      18°  WolverhamptonWOL
# 18        19°  SouthamptonSOU
# 19            20°  EvertonEVE
# Tabela não encontrada
