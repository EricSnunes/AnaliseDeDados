# %% [markdown]
# <a href="https://colab.research.google.com/github/EricSnunes/AnaliseDeDados/blob/main/PrencherDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Dados242.xlsx')
df
# Out:
#           Sexo  Idade  Altura   Peso   Renda          Profissão do pai ou mãe  \
# 0     FEMININO     21     160   65.0     NaN                      VETERINARIO
# 1     FEMININO     20     177   53.0     NaN                          Músico
# 2    Masculino     20     176   66.0     NaN                         Corretor
# 3    Masculino     20     171   76.0     NaN                         Contador
# 4    masculino     21     173   72.0     NaN                         contador
# 5   Masculino      20     173  124.0  5000.0  Coordenador comercial/ Diarista
# 6     Feminino     23     175   69.0     NaN                Gerente de vendas
# 7     Feminino     21     159   51.0  1400.0                        Vendedora
# 8     Feminino     22     154   60.0  1900.0                      Serralheiro
# 9     Feminino     20     167   52.0  1100.0                         Mecânico
# 10    FEMININO     20     165   65.0     NaN                        Policial
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sexo                         29 non-null     object
#  1   Idade                        30 non-null     int64
#  2   Altura                       30 non-null     int64
#  3   Peso                         29 non-null     float64
#  4   Renda                        14 non-null     float64
#  5   Profissão do pai ou mãe      27 non-null     object
#  6   Numero de moradores          30 non-null     int64
#  7   número de banheiros na casa  30 non-null     int64
#  8   Gênero musical               30 non-null     object
#  9   Distância da Faculdade       30 non-null     float64
#  10  Número de Pets na casa       30 non-null     int64
#  11  numero do calçado            30 non-null     object
#  12  Hobby                        29 non-null     object
# ...

# %%
df_limpo = df.dropna()
df_limpo
# Out:
#           Sexo  Idade  Altura   Peso   Renda          Profissão do pai ou mãe  \
# 5   Masculino      20     173  124.0  5000.0  Coordenador comercial/ Diarista
# 7     Feminino     21     159   51.0  1400.0                        Vendedora
# 8     Feminino     22     154   60.0  1900.0                      Serralheiro
# 9     Feminino     20     167   52.0  1100.0                         Mecânico
# 12   Masculino     23     173   82.0  1550.0                Contador/Finanças
# 13    Feminino     20     167   85.0  2623.0              Gerente de projetos
# 15   Feminino      21     155   50.0  1100.0                   administrador
# 17   Masculino     22     176   65.0  1200.0                      Confeiteiro
# 19   Masculino     22     170   78.0   100.0                  Gerente de loja
# 27   Masculino     21     175   60.0     0.0                Assistente social
# 28   Masculino     21     177   55.0     0.0   Tec. Enfermagem / Publicitario
# ...

# %%
#preencher dados faltantes com a media da coluna
media_renda = df['Renda'].mean()
df['Renda'] = df['Renda'].fillna(media_renda)
df
# Out:
#           Sexo  Idade  Altura   Peso        Renda  \
# 0     FEMININO     21     160   65.0  1576.642857
# 1     FEMININO     20     177   53.0  1576.642857
# 2    Masculino     20     176   66.0  1576.642857
# 3    Masculino     20     171   76.0  1576.642857
# 4    masculino     21     173   72.0  1576.642857
# 5   Masculino      20     173  124.0  5000.000000
# 6     Feminino     23     175   69.0  1576.642857
# 7     Feminino     21     159   51.0  1400.000000
# 8     Feminino     22     154   60.0  1900.000000
# 9     Feminino     20     167   52.0  1100.000000
# 10    FEMININO     20     165   65.0  1576.642857
# 11    FEMININO     19     171   60.0  1576.642857
# 12   Masculino     23     173   82.0  1550.000000
# 13    Feminino     20     167   85.0  2623.000000
# 14    FEMININO     22     166   57.0  1576.642857
# 15   Feminino      21     155   50.0  1100.000000
# 16   Feminino      20     161   65.0  1576.642857
# 17   Masculino     22     176   65.0  1200.000000
# ...

# %%
#preencher dados faltantes com a media da coluna
media_peso = df['Peso'].mean()
df['Peso'] = df['Peso'].fillna(media_peso)
df
# Out:
#           Sexo  Idade  Altura        Peso        Renda  \
# 0     FEMININO     21     160   65.000000  1576.642857
# 1     FEMININO     20     177   53.000000  1576.642857
# 2    Masculino     20     176   66.000000  1576.642857
# 3    Masculino     20     171   76.000000  1576.642857
# 4    masculino     21     173   72.000000  1576.642857
# 5   Masculino      20     173  124.000000  5000.000000
# 6     Feminino     23     175   69.000000  1576.642857
# 7     Feminino     21     159   51.000000  1400.000000
# 8     Feminino     22     154   60.000000  1900.000000
# 9     Feminino     20     167   52.000000  1100.000000
# 10    FEMININO     20     165   65.000000  1576.642857
# 11    FEMININO     19     171   60.000000  1576.642857
# 12   Masculino     23     173   82.000000  1550.000000
# 13    Feminino     20     167   85.000000  2623.000000
# 14    FEMININO     22     166   57.000000  1576.642857
# 15   Feminino      21     155   50.000000  1100.000000
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sexo                         29 non-null     object
#  1   Idade                        30 non-null     int64
#  2   Altura                       30 non-null     int64
#  3   Peso                         30 non-null     float64
#  4   Renda                        30 non-null     float64
#  5   Profissão do pai ou mãe      27 non-null     object
#  6   Numero de moradores          30 non-null     int64
#  7   número de banheiros na casa  30 non-null     int64
#  8   Gênero musical               30 non-null     object
#  9   Distância da Faculdade       30 non-null     float64
#  10  Número de Pets na casa       30 non-null     int64
#  11  numero do calçado            30 non-null     object
#  12  Hobby                        29 non-null     object
# ...

# %%
#selecione apenas as colunas numericas
datanum.to_csv('dados242limpos.csv', index=False)
