# %% [markdown]
# <a href="https://colab.research.google.com/github/EricSnunes/AnaliseDeDados/blob/main/PrimeiraMatrizDeCorrel%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Dados.xlsx')
display(df)
# Out:
#           Sexo  Idade  Altura   Peso   Renda          Profissao  Moradores  \
# 0    Feminino      19     171   60.0     NaN                NaN          3
# 1    Masculino     20     193   98.0  2100.0                NaN          5
# 2    Feminino      20     167   52.0  1100.0           Mecânico          3
# 3          NaN     20     173   95.0  4000.0  Analista de dados          4
# 4    Masculino     20     175    NaN     NaN         Jornalista          4
# 5   Masculino      20     173  124.0  5000.0        Coordenador          3
# 6    Feminino      20     177   63.0     NaN            Músico           3
# 7    Feminino      20     165   65.0     NaN          Policial           4
# 8    Feminino      20     161   65.0     NaN           Mecânico          4
# 9    Masculino     20     176   66.0     NaN           Corretor          3
# 10   Masculino     20     171   76.0     NaN           Contador          3
# ...

# %%
data = pd.get_dummies(df, columns=['Sexo'])
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Idade            30 non-null     int64
#  1   Altura           30 non-null     int64
#  2   Peso             29 non-null     float64
#  3   Renda            14 non-null     float64
#  4   Profissao        27 non-null     object
#  5   Moradores        30 non-null     int64
#  6   Banheiros        30 non-null     int64
#  7   Musica           30 non-null     object
#  8   Distancia        30 non-null     float64
#  9   Pets             30 non-null     int64
#  10  Calcado          30 non-null     int64
#  11  Hobby            29 non-null     object
#  12  Sexo_Feminino    30 non-null     bool
#  13  Sexo_Masculino   30 non-null     bool
#  14  Sexo_Masculino   30 non-null     bool
# dtypes: bool(3), float64(3), int64(6), object(3)
# memory usage: 3.0+ KB
# None

# %%
display(data)
# Out:
#     Idade  Altura   Peso   Renda          Profissao  Moradores  Banheiros  \
# 0      19     171   60.0     NaN                NaN          3          1
# 1      20     193   98.0  2100.0                NaN          5          4
# 2      20     167   52.0  1100.0           Mecânico          3          2
# 3      20     173   95.0  4000.0  Analista de dados          4          2
# 4      20     175    NaN     NaN         Jornalista          4          4
# 5      20     173  124.0  5000.0        Coordenador          3          1
# 6      20     177   63.0     NaN            Músico           3          1
# 7      20     165   65.0     NaN          Policial           4          4
# 8      20     161   65.0     NaN           Mecânico          4          3
# 9      20     176   66.0     NaN           Corretor          3          4
# 10     20     171   76.0     NaN           Contador          3          1
# 11     20     167   75.0  2623.0            Gerente          2          1
# ...

# %%
numeric_columns = data.select_dtypes(include=['float64','int64', 'boolean'])
display(numeric_columns)
# Out:
#     Idade  Altura   Peso   Renda  Moradores  Banheiros  Distancia  Pets  \
# 0      19     171   60.0     NaN          3          1      15.00     1
# 1      20     193   98.0  2100.0          5          4      34.60     0
# 2      20     167   52.0  1100.0          3          2      49.00     3
# 3      20     173   95.0  4000.0          4          2      12.00     2
# 4      20     175    NaN     NaN          4          4       0.55     0
# 5      20     173  124.0  5000.0          3          1      20.00     1
# 6      20     177   63.0     NaN          3          1       8.00     0
# 7      20     165   65.0     NaN          4          4      27.00     2
# 8      20     161   65.0     NaN          4          3       7.00     1
# 9      20     176   66.0     NaN          3          4       3.40     0
# 10     20     171   76.0     NaN          3          1      18.00     2
# 11     20     167   75.0  2623.0          2          1      13.00     2
# ...

# %%
correlation_matrix = numeric_columns.corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlação')
plt.show()
