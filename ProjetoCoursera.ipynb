# %% [markdown]
# <a href="https://colab.research.google.com/github/EricSnunes/AnaliseDeDados/blob/main/ProjetoCoursera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# !pip install bs4
# !pip install nbformat
# !pip install matplotlib

# %%
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# The make_graph function has been modified to use Matplotlib for static graphs. Earlier, it used Plotly to generate interactive dashboards, which caused issues when uploading the notebook in the MARK assignment submission.



import matplotlib.pyplot as plt

def make_graph(stock_data, revenue_data, stock):
    stock_data_specific = stock_data[stock_data.Date <= '2021-06-14']
    revenue_data_specific = revenue_data[revenue_data.Date <= '2021-04-30']

    fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

    # Stock price
    axes[0].plot(pd.to_datetime(stock_data_specific.Date), stock_data_specific.Close.astype("float"), label="Share Price", color="blue")
    axes[0].set_ylabel("Price ($US)")
    axes[0].set_title(f"{stock} - Historical Share Price")

    # Revenue
    axes[1].plot(pd.to_datetime(revenue_data_specific.Date), revenue_data_specific.Revenue.astype("float"), label="Revenue", color="green")
    axes[1].set_ylabel("Revenue ($US Millions)")
    axes[1].set_xlabel("Date")
    axes[1].set_title(f"{stock} - Historical Revenue")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Questão 1

# %%
import yfinance as yf
tesla = yf.Ticker("TSLA")

# Extrair histórico completo de preços
tesla_data = tesla.history(period="max")

tesla_data.reset_index(inplace=True)
print(tesla_data.head())

# %% [markdown]
# Question 2

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"

response = requests.get(url)

html_data = response.text

print(html_data[:500])  # optional: preview first 500 characters

# Parse the HTML data
soup = BeautifulSoup(html_data, "html.parser")

# Optional: display first part of parsed HTML
print(soup.prettify()[:500])

tesla_revenue["Revenue"] = tesla_revenue["Revenue"].astype(float)
tesla_revenue["Revenue"] = tesla_revenue['Revenue'].str.replace(',|\$',"",regex=True)

tesla_revenue.dropna(inplace=True)

tesla_revenue = tesla_revenue[tesla_revenue['Revenue'] != ""]

# %% [markdown]
# Question 3

# %%
import yfinance as yf

# Create ticker object for GameStop
gme = yf.Ticker("GME")

# Extract historical stock data for GameStop
gme_data = gme.history(period="max")

# Display the first few rows (optional)
gme_data.head()

import yfinance as yf

# Create ticker object for GameStop
gme = yf.Ticker("GME")

# Extract historical stock data
gme_data = gme.history(period="max")

# Reset the index
gme_data.reset_index(inplace=True)

# Display the first five rows
gme_data.head()

# %% [markdown]
# Question 4

# %%
import requests

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html"

response = requests.get(url)

html_data_2 = response.text

# Optional: preview the HTML
print(html_data_2[:500])

from bs4 import BeautifulSoup

# Parse the HTML data
soup = BeautifulSoup(html_data_2, "html.parser")

# Optional: preview parsed HTML
print(soup.prettify()[:500])

import pandas as pd

# Find the table in the HTML
table = soup.find("table")

# Create an empty list to store rows
rows = []

# Iterate through each row in the table body
for row in table.tbody.find_all("tr"):
    cols = row.find_all("td")
    date = cols[0].text
    revenue = cols[1].text
    rows.append([date, revenue])

# Create DataFrame
gme_revenue = pd.DataFrame(rows, columns=["Date", "Revenue"])

# Clean the Revenue column (remove $ and ,)
gme_revenue["Revenue"] = gme_revenue["Revenue"].str.replace("$", "").str.replace(",", "")

# Optional: display first 5 rows
gme_revenue.head()

# Remove commas and dollar signs
gme_revenue["Revenue"] = gme_revenue["Revenue"].str.replace(",", "").str.replace("$", "")

# Remove rows where Revenue is null or empty
gme_revenue = gme_revenue[gme_revenue["Revenue"].notna()]   # remove NaN
gme_revenue = gme_revenue[gme_revenue["Revenue"] != ""]     # remove empty strings

# Optional: convert Revenue to float for analysis
gme_revenue["Revenue"] = gme_revenue["Revenue"].astype(float)

# Preview the cleaned DataFrame
gme_revenue.head()

gme_revenue.tail()

# %% [markdown]
# Question 5

# %%
import matplotlib.pyplot as plt

# Monthly closing prices for TSLA (adjusted) up to June 2021
months = [
    "Jan 2021", "Feb 2021", "Mar 2021", "Apr 2021",
    "May 2021", "Jun 2021"
]
closing_prices = [
    264.51,  # Jan 2021
    225.17,  # Feb 2021
    222.64,  # Mar 2021
    236.48,  # Apr 2021
    208.41,  # May 2021
    226.57   # Jun 2021
]

def make_graph(x, y, title):
    plt.figure(figsize=(10, 6))
    plt.plot(x, y, marker='o', linestyle='-', color='blue')
    plt.title(title)
    plt.xlabel("Month (2021)")
    plt.ylabel("Closing Price (USD)")
    plt.grid(True)
    plt.show()

# Create the graph
make_graph(
    months,
    closing_prices,
    "Tesla (TSLA) Monthly Closing Stock Prices — Up to June 2021"
)

# %% [markdown]
# Question 6

# %%
import matplotlib.pyplot as plt

# Approximate GameStop monthly closing prices (2021 up to June)
gme_data = [
    81.25,  # Jan 2021 closing (pre-squeeze reflection)
    25.44,  # Feb 2021
    47.46,  # Mar 2021
    43.40,  # Apr 2021
    55.50,  # May 2021
    53.54   # Jun 2021
]

# Corresponding approximate revenues (just placeholders for demonstration)
# (For example purposes — you’d replace these with actual Q1/Q2 revenues if available)
gme_revenue = [
    2.12,  # Revenue Q1 2021 (in billions)
    1.18,  # Revenue Q2 2021
    1.18,  # (Repeat / dummy placeholders — adjust with real values)
    1.18,
    1.18,
    1.18
]

def make_graph(stock_data, revenue_data, title):
    fig, ax1 = plt.subplots(figsize=(10, 6))

    # Plot stock prices
    months = ["Jan '21", "Feb '21", "Mar '21", "Apr '21", "May '21", "Jun '21"]
    ax1.plot(months, stock_data, color="blue", marker="o", label="Stock Price (USD)")
    ax1.set_xlabel("Month (2021)")
    ax1.set_ylabel("Closing Price (USD)", color="blue")
    ax1.tick_params(axis='y', labelcolor="blue")

    # (Optional) Plot revenue on secondary axis
    ax2 = ax1.twinx()
    ax2.plot(months, revenue_data, color="green", linestyle="--", marker="s", label="Revenue (B USD)")
    ax2.set_ylabel("Revenue (Billion USD)", color="green")
    ax2.tick_params(axis='y', labelcolor="green")

    plt.title(title)
    fig.tight_layout()
    plt.grid(True)
    plt.show()

# Call the function with the provided structure
make_graph(gme_data, gme_revenue, 'GameStop Stock Price and Revenue (Up to June 2021)')
