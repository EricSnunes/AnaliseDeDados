# %% [markdown]
# <a href="https://colab.research.google.com/github/EricSnunes/AnaliseDeDados/blob/main/PrimeiroDataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def saudacao(nome):
  return f"Olá,{nome}!"
  print(saudacao("Ana"))

  def soma(a, b):
    return a + b
    print(soma(2, 3))

    nome = input("Digite seu nome: ")
    print(f"Olá, {nome}!")

# %%
contador = 0
while contador < 5:
  print(contador)
  contador += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import pandas as pd
#criando um dataFrame
dados = {
    'Nome':['Ana' , 'João', 'Maria'],
    'Idade': [23, 34, 29]
}
df = pd.DataFrame(dados)
display(df)
# Out:
#     Nome  Idade
# 0    Ana     23
# 1   João     34
# 2  Maria     29
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Idade'].plot(kind='hist', bins=20, title='Idade')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Nome').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Idade'].plot(kind='line', figsize=(8, 4), title='Idade')
# ...

# %%
import matplotlib.pyplot as plt
#Criando um grafico simples
idades = [23, 34, 29]
plt.plot(idades)
plt.ylabel('Idades')
plt.show()

# %%
import numpy as np
#criando um arry numfy
array = np.array([1, 2, 3, 4, 5])
print (array)
print (array * 2)
# Out:
# [1 2 3 4 5]
# [ 2  4  6  8 10]
